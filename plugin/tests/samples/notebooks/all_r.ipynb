# %%
library(ggplot2)
library(dplyr)
df <- read.csv('cohort.csv')

# %%
summarise_fn <- function(x) {
  m <- mean(x)
  s <- sd(x)
  c(m, s)
}

# %%
groups <- c('a', 'b', 'c')
results <- read.csv('results.csv')
merged <- merge(results, c('id', 'group'), by = 'id')
